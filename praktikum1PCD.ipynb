# %% [markdown]
# <a href="https://colab.research.google.com/github/aaril011/Praktikum_PCD/blob/main/praktikum1PCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Menngimport Library
import cv2
import matplotlib.pyplot as plt

# %%
#membaca gambar
img = cv2.imread('/content/IMG-20230811-WA0128.jpg')

# %%
#Konversi gambar ke RGB
RGB = cv2.cvtColor (img, cv2.COLOR_BGR2RGB)

# %%
#mengubah gambar ke grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#mengubah gambar ke binner
ret, biner_img = cv2.threshold(gray_img, 128, 255,cv2.THRESH_BINARY)

# %%
#menampilkan gambar
titles = ['Original Image', 'RGB', 'Gray Image', 'Biner Image']
images = [img, RGB, gray_img, biner_img]

fig, axes = plt.subplots(1,4, figsize=(12,8))
fig.subplots_adjust(wspace=0.5, hspace=0.5)

for i in range(4):
  plt.subplot(1, 4, i + 1)
  plt.imshow(images[i], 'gray', vmin=0, vmax=255)
  plt.title(titles[i])
  plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/aaril011/Praktikum_PCD/blob/main/transformasi_negatif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img_path = "mammogram.jpeg"
img = cv2.imread(img_path)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
negative_img = 255 - gray_img

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Gambar Asli')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(negative_img, cmap='gray')
plt.title('Negatif Gambar')
plt.axis('off')

plt.show()
